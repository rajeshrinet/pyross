# %%
# %%capture
## compile PyRoss for this notebook
import os
owd = os.getcwd()
os.chdir('../../')
# %run setup.py install
os.chdir(owd)

# %%
import numpy as np
import pyross
import matplotlib.pyplot as plt
from matplotlib import rc; rc('text', usetex=True)

# %% [markdown]
# ## Age-structures

# %%
M=16  ## number of age classes
my_data = np.genfromtxt('../data/age_structures/China-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

chinaM = 100*aM/np.sum(2*aM)
chinaF = 100*aF/np.sum(2*aF)

# %%
my_data = np.genfromtxt('../data/age_structures/Denmark-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

denM = 100*aM/np.sum(2*aM)
denF = 100*aF/np.sum(2*aF)

# %%
my_data = np.genfromtxt('../data/age_structures/UK.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

ukM = 100*aM/np.sum(2*aM)
ukF = 100*aF/np.sum(2*aF)

# %%
my_data = np.genfromtxt('../data/age_structures/Italy-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

italyM = 100*aM/np.sum(2*aM)
italyF = 100*aF/np.sum(2*aF)

# %% [markdown]
# ## Contact structures

# %%
chCH, chCW, chCS, chCO = pyross.contactMatrix.China()
deCH, deCW, deCS, deCO = pyross.contactMatrix.Denmark()
ukCH, ukCW, ukCS, ukCO = pyross.contactMatrix.UK()

# %%
fig = plt.figure(figsize=(22, 26), dpi=200);  
plt.rcParams.update({'font.size': 20})


sp =  fig.add_subplot(3, 4, 1);
sAge = np.arange((np.size(aM)))
plt.barh(sAge, ukM, color="#348ABD", label='Male', alpha=0.8)
plt.barh(sAge, -ukF,color='#A60628', label='Female', alpha=0.8)
plt.legend(); plt.grid() 
plt.yticks(np.arange(0, 21, 4), ('0-4', '20-24', '40-44', '60-64', '80-84', '100'));
plt.xticks(np.arange(-4, 5, 2), ('4\%', '2\%', '0\%', '2\%', '4\%'));
plt.ylabel('Age')

sp =  fig.add_subplot(3, 4, 2);
plt.pcolor(ukCH, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Home)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 4, 3);
plt.pcolor(ukCW, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 4, 4);
plt.pcolor(ukCS, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (School)')
plt.xlabel('Age of contact')



sp =  fig.add_subplot(3, 4, 5);
sAge = np.arange((np.size(aM)))
plt.barh(sAge, chinaM, color="#348ABD", label='Male', alpha=0.8)
plt.barh(sAge, -chinaF,color='#A60628', label='Female', alpha=0.8)
plt.legend(); plt.grid() 
plt.yticks(np.arange(0, 21, 4), ('0-4', '20-24', '40-44', '60-64', '80-84', '100'));
plt.xticks(np.arange(-4, 5, 2), ('4\%', '2\%', '0\%', '2\%', '4\%'));
plt.ylabel('Age')

sp =  fig.add_subplot(3, 4, 6);
plt.pcolor(chCH, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Home)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 4, 7);
plt.pcolor(chCW, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 4, 8);
plt.pcolor(chCS, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 4, 9);
sAge = np.arange((np.size(aM)))
plt.barh(sAge, italyM, color="#348ABD", label='Male', alpha=0.8)
plt.barh(sAge, -italyF,color='#A60628', label='Female', alpha=0.8)
plt.legend(); plt.grid() 
plt.yticks(np.arange(0, 21, 4), ('0-4', '20-24', '40-44', '60-64', '80-84', '100'));
plt.xticks(np.arange(-4, 5, 2), ('4\%', '2\%', '0\%', '2\%', '4\%'));
plt.ylabel('Age')

sp =  fig.add_subplot(3, 4, 10);
plt.pcolor(deCH, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Home)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 4, 11);
plt.pcolor(deCW, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 4, 12);
plt.pcolor(deCS, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')
# Out:
# Text(0.5, 0, 'Age of contact')

# %%
C=ukCH+ukCW+ukCS+ukCO

# epidemic parameters
alpha = 0.              # symptomatic fraction
beta  = 1               # contact rate parameter
gamma = 1/7             # recovery rate 
fsa   = 1               # suppresion of contact by symptomatics

Ni=ukM+ukF

# matrix for linearised dynamics
L0 = np.zeros((M, M))
L  = np.zeros((2*M, 2*M))

for i in range(M):
    for j in range(M):
        L0[i,j]=C[i,j]*Ni[i]/Ni[j]


L[0:M, 0:M]     = alpha*beta/gamma*L0
L[0:M, M:2*M]   = fsa*alpha*beta/gamma*L0
L[M:2*M, 0:M]   = ((1-alpha)*beta/gamma)*L0
L[M:2*M, M:2*M] = fsa*((1-alpha)*beta/gamma)*L0


r0 = np.max(np.linalg.eigvals(L))
print("The basic reproductive ratio for these parameters is", r0)
# Out:
# The basic reproductive ratio for these parameters is (81.75599447582672+0j)

# %%
C=ukCH

# epidemic parameters
alpha = 0.              # symptomatic fraction
beta  = 1               # contact rate parameter
gamma = 1/7             # recovery rate 
fsa   = 1               # suppresion of contact by symptomatics

Ni=ukM+ukF

# matrix for linearised dynamics
L0 = np.zeros((M, M))
L  = np.zeros((2*M, 2*M))

for i in range(M):
    for j in range(M):
        L0[i,j]=C[i,j]*Ni[i]/Ni[j]


L[0:M, 0:M]     = alpha*beta/gamma*L0
L[0:M, M:2*M]   = fsa*alpha*beta/gamma*L0
L[M:2*M, 0:M]   = ((1-alpha)*beta/gamma)*L0
L[M:2*M, M:2*M] = fsa*((1-alpha)*beta/gamma)*L0


r0 = np.max(np.linalg.eigvals(L))
print("The basic reproductive ratio for these parameters is", r0)
# Out:
# The basic reproductive ratio for these parameters is (20.91298427906979+0j)

# %%
C=chCH+chCW+chCS+chCO

# epidemic parameters
alpha = 0.              # symptomatic fraction
beta  = 1               # contact rate parameter
gamma = 1/7             # recovery rate 
fsa   = 1               # suppresion of contact by symptomatics

Ni=chinaM+chinaF

# matrix for linearised dynamics
L0 = np.zeros((M, M))
L  = np.zeros((2*M, 2*M))

for i in range(M):
    for j in range(M):
        L0[i,j]=C[i,j]*Ni[i]/Ni[j]


L[0:M, 0:M]     = alpha*beta/gamma*L0
L[0:M, M:2*M]   = fsa*alpha*beta/gamma*L0
L[M:2*M, 0:M]   = ((1-alpha)*beta/gamma)*L0
L[M:2*M, M:2*M] = fsa*((1-alpha)*beta/gamma)*L0


r0 = np.max(np.linalg.eigvals(L))
print("The basic reproductive ratio for these parameters is", r0)
# Out:
# The basic reproductive ratio for these parameters is (117.21386704477355+0j)

# %%
C=deCH+deCW+deCS+deCO

# epidemic parameters
alpha = 0.              # symptomatic fraction
beta  = 1               # contact rate parameter
gamma = 1/7             # recovery rate 
fsa   = 1               # suppresion of contact by symptomatics

Ni=denM+denF

# matrix for linearised dynamics
L0 = np.zeros((M, M))
L  = np.zeros((2*M, 2*M))

for i in range(M):
    for j in range(M):
        L0[i,j]=C[i,j]*Ni[i]/Ni[j]


L[0:M, 0:M]     = alpha*beta/gamma*L0
L[0:M, M:2*M]   = fsa*alpha*beta/gamma*L0
L[M:2*M, 0:M]   = ((1-alpha)*beta/gamma)*L0
L[M:2*M, M:2*M] = fsa*((1-alpha)*beta/gamma)*L0


r0 = np.max(np.linalg.eigvals(L))
print("The basic reproductive ratio for these parameters is", r0)
# Out:
# The basic reproductive ratio for these parameters is (104.27730168964042+0j)
