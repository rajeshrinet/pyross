# %%
# %%capture
## compile PyRoss for this notebook
import os
owd = os.getcwd()
os.chdir('../../')
# %run setup.py install
os.chdir(owd)

# %%
import numpy as np
import pyross
import matplotlib.pyplot as plt
from matplotlib import rc; rc('text', usetex=True)

# %% [markdown]
# ## Age-structures

# %%
M=16  ## number of age classes
my_data = np.genfromtxt('../data/age_structures/China-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

print(aM)
chinaM = 100*aM/np.sum(2*aM)
chinaF = 100*aF/np.sum(2*aF)
# Out:
# [4.5106267e+07 4.6319087e+07 4.5044032e+07 4.4286173e+07 4.6956410e+07
#  5.4633535e+07 6.5544747e+07 4.9370823e+07 5.1155493e+07 6.2836913e+07
#  6.0946291e+07 4.7588180e+07 3.8607054e+07 3.5185041e+07 1.9746314e+07
#  1.1801212e+07 6.8086500e+06 2.7871030e+06 7.4888100e+05 1.4032200e+05
#  1.1731000e+04]

# %%
my_data = np.genfromtxt('../data/age_structures/Denmark-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

print(aM)
denM = 100*aM/np.sum(2*aM)
denF = 100*aF/np.sum(2*aF)
# Out:
# [1.55083e+05 1.56940e+05 1.74005e+05 1.74082e+05 1.94805e+05 2.01921e+05
#  1.74221e+05 1.60544e+05 1.83041e+05 1.92779e+05 2.14342e+05 1.89732e+05
#  1.66561e+05 1.55332e+05 1.69371e+05 1.01656e+05 6.09520e+04 2.94240e+04
#  1.18900e+04 2.78600e+03 2.05000e+02]

# %%
my_data = np.genfromtxt('../data/age_structures/India-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

print(aM)
indiaM = 100*aM/np.sum(2*aM)
indiaF = 100*aF/np.sum(2*aF)
# Out:
# [6.1184852e+07 6.2910580e+07 6.6812183e+07 6.6525043e+07 6.4478247e+07
#  6.1604481e+07 5.8243202e+07 5.2838830e+07 4.5523908e+07 3.9881404e+07
#  3.4484803e+07 2.9500956e+07 2.4129236e+07 1.8287177e+07 1.0982591e+07
#  6.8618620e+06 3.7466440e+06 1.5542750e+06 4.6109300e+05 1.0239800e+05
#  1.5806000e+04]

# %%
my_data = np.genfromtxt('../data/age_structures/Italy-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

italyM = 100*aM/np.sum(2*aM)
italyF = 100*aF/np.sum(2*aF)

# %% [markdown]
# ## Contact structures

# %%
chCH, chCW, chCS, chCO = pyross.contactMatrix.China()
deCH, deCW, deCS, deCO = pyross.contactMatrix.Denmark()
inCH, inCW, inCS, inCO = pyross.contactMatrix.India()
itCH, itCW, itCS, itCO = pyross.contactMatrix.Italy()

# %%
fig = plt.figure(figsize=(20, 22), dpi=200);  
plt.rcParams.update({'font.size': 20})


sp =  fig.add_subplot(3, 3, 1);
sAge = np.arange((np.size(aM)))
plt.barh(sAge, indiaM, color="#348ABD", label='Male', alpha=0.8)
plt.barh(sAge, -indiaF,color='#A60628', label='Female', alpha=0.8)
plt.legend(); plt.grid() 
plt.yticks(np.arange(0, 21, 4), ('0-4', '20-24', '40-44', '60-64', '80-84', '100'));
plt.xticks(np.arange(-4, 5, 2), ('4\%', '2\%', '0\%', '2\%', '4\%'));
plt.ylabel('Age')

sp =  fig.add_subplot(3, 3, 2);
plt.pcolor(inCH, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Home)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 3, 3);
plt.pcolor(inCW, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 3, 4);
sAge = np.arange((np.size(aM)))
plt.barh(sAge, chinaM, color="#348ABD", label='Male', alpha=0.8)
plt.barh(sAge, -chinaF,color='#A60628', label='Female', alpha=0.8)
plt.legend(); plt.grid() 
plt.yticks(np.arange(0, 21, 4), ('0-4', '20-24', '40-44', '60-64', '80-84', '100'));
plt.xticks(np.arange(-4, 5, 2), ('4\%', '2\%', '0\%', '2\%', '4\%'));
plt.ylabel('Age')

sp =  fig.add_subplot(3, 3, 5);
plt.pcolor(chCH, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Home)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 3, 6);
plt.pcolor(chCW, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 3, 7);
sAge = np.arange((np.size(aM)))
plt.barh(sAge, italyM, color="#348ABD", label='Male', alpha=0.8)
plt.barh(sAge, -italyF,color='#A60628', label='Female', alpha=0.8)
plt.legend(); plt.grid() 
plt.yticks(np.arange(0, 21, 4), ('0-4', '20-24', '40-44', '60-64', '80-84', '100'));
plt.xticks(np.arange(-4, 5, 2), ('4\%', '2\%', '0\%', '2\%', '4\%'));
plt.ylabel('Age')

sp =  fig.add_subplot(3, 3, 8);
plt.pcolor(itCH, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Home)')
plt.xlabel('Age of contact')


sp =  fig.add_subplot(3, 3, 9);
plt.pcolor(itCW, cmap=plt.cm.get_cmap('GnBu', 10)); plt.axis('square')# plt.clim(-0*np.max(MU), 0.3*np.max(MU));
plt.locator_params(nbins=6)
plt.xticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.yticks(np.arange(0, 17, 4), ('0', '20', '40', '60', '80'));
plt.ylabel('Age of contact (Work)')
plt.xlabel('Age of contact')
# Out:
# Text(0.5, 0, 'Age of contact')

# %%
C=inCH+inCW+inCS+inCO

# epidemic parameters
alpha = 0.              # symptomatic fraction
beta  = 1               # contact rate parameter
gamma = 1/7             # recovery rate 
fsa   = 1               # suppresion of contact by symptomatics

Ni=indiaM+indiaF

# matrix for linearised dynamics
L0 = np.zeros((M, M))
L  = np.zeros((2*M, 2*M))

for i in range(M):
    for j in range(M):
        L0[i,j]=C[i,j]*Ni[i]/Ni[j]


L[0:M, 0:M]     = alpha*beta/gamma*L0
L[0:M, M:2*M]   = fsa*alpha*beta/gamma*L0
L[M:2*M, 0:M]   = ((1-alpha)*beta/gamma)*L0
L[M:2*M, M:2*M] = fsa*((1-alpha)*beta/gamma)*L0


r0 = np.max(np.linalg.eigvals(L))
print("The basic reproductive ratio for these parameters is", r0)
# Out:
# The basic reproductive ratio for these parameters is (135.84222325449318+0j)

# %%
C=itCH+itCW+itCS+itCO

# epidemic parameters
alpha = 0.              # symptomatic fraction
beta  = 1               # contact rate parameter
gamma = 1/7             # recovery rate 
fsa   = 1               # suppresion of contact by symptomatics

Ni=italyM+italyF

# matrix for linearised dynamics
L0 = np.zeros((M, M))
L  = np.zeros((2*M, 2*M))

for i in range(M):
    for j in range(M):
        L0[i,j]=C[i,j]*Ni[i]/Ni[j]


L[0:M, 0:M]     = alpha*beta/gamma*L0
L[0:M, M:2*M]   = fsa*alpha*beta/gamma*L0
L[M:2*M, 0:M]   = ((1-alpha)*beta/gamma)*L0
L[M:2*M, M:2*M] = fsa*((1-alpha)*beta/gamma)*L0


r0 = np.max(np.linalg.eigvals(L))
print("The basic reproductive ratio for these parameters is", r0)
# Out:
# The basic reproductive ratio for these parameters is (119.3151056656333+0j)

# %%
C=chCH+chCW+chCS+chCO

# epidemic parameters
alpha = 0.              # symptomatic fraction
beta  = 1               # contact rate parameter
gamma = 1/7             # recovery rate 
fsa   = 1               # suppresion of contact by symptomatics

Ni=chinaM+chinaF

# matrix for linearised dynamics
L0 = np.zeros((M, M))
L  = np.zeros((2*M, 2*M))

for i in range(M):
    for j in range(M):
        L0[i,j]=C[i,j]*Ni[i]/Ni[j]


L[0:M, 0:M]     = alpha*beta/gamma*L0
L[0:M, M:2*M]   = fsa*alpha*beta/gamma*L0
L[M:2*M, 0:M]   = ((1-alpha)*beta/gamma)*L0
L[M:2*M, M:2*M] = fsa*((1-alpha)*beta/gamma)*L0


r0 = np.max(np.linalg.eigvals(L))
print("The basic reproductive ratio for these parameters is", r0)
# Out:
# The basic reproductive ratio for these parameters is (117.21386704477355+0j)
