# %%
# %%capture
## compile PyRoss for this notebook
import os
owd = os.getcwd()
os.chdir('../../')
# %run setup.py install
os.chdir(owd)

# %%
# %matplotlib inline
import numpy as np
import pyross
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
## population and age classes
M=16  ## number of age classes

my_data = np.genfromtxt('../data/age_structures/UK.csv', delimiter=',', skip_header=1)
Ni = (my_data[:, 1]+ my_data[:, 2])[0:M]

# %%
# Get individual contact matrices
CH, CW, CS, CO = pyross.contactMatrix.India()

# %%
# Generate class with contact matrix for SIR model with UK contact structure
generator = pyross.contactMatrix.ContactMatrixFunction(CH, CW, CS, CO)

# %%
Tf=63;  Nf=900 
times= [21, Tf] # temporal boundaries between different contact-behaviour

aW, aS, aO = 0.0, 0.0, 0.0

# prefactors for CW, CS, CO:
interventions = [[1.0,1.0,1.0],      # before first time
                 [aW, aS, aO],       # between first and second time
                ]         

# generate corresponding contact matrix function
C = generator.interventions_temporal(times=times,interventions=interventions)

# %%
beta  = 0.01646692     # contact rate parameter
gIa   = 1./7            # recovery rate of asymptomatic infectives 
gIs   = 1./7            # recovery rate of symptomatic infectives 
alpha = 0.              # asymptomatic fraction
fsa   = 1               # suppresion of contact by symptomatics


# initial conditions    
Is_0 = np.zeros((M));  Is_0[6:13]=14;  Is_0[2:6]=13
Ia_0 = np.zeros((M))
R_0  = np.zeros((M))
S_0  = Ni - (Ia_0 + Is_0 + R_0)


parameters = {'alpha':alpha,'beta':beta, 'gIa':gIa,'gIs':gIs,'fsa':fsa}
model = pyross.deterministic.SIR(parameters, M, Ni)

contactMatrix=C

# start simulation
dataSIR =model.simulate(S_0, Ia_0, Is_0, contactMatrix, Tf, Nf)
IsSIR = model.Is(dataSIR)

# %%
beta  = 0.027      # contact rate parameter
gIa   = 1./7            # recovery rate of asymptomatic infectives 
gE    = 1/2.72
gIs   = 1./7            # recovery rate of symptomatic infectives 
alpha = 0.              # asymptomatic fraction
fsa   = 1               # suppresion of contact by symptomatics


# initial conditions    
Is_0 = np.zeros((M));  Is_0[6:13]=14;  Is_0[2:6]=13
Ia_0 = np.zeros((M))
E_0 = np.zeros((M)); 
R_0  = np.zeros((M))
S_0  = Ni - (Ia_0 + Is_0 + R_0)


parameters = {'alpha':alpha,'beta':beta, 'gIa':gIa,'gIs':gIs,'gE':gE,'fsa':fsa}
model = pyross.deterministic.SEIR(parameters, M, Ni)

contactMatrix=C

# start simulation
dataSEIR =model.simulate(S_0, E_0, Ia_0, Is_0, C, Tf, Nf)
IsSEIR = model.Is(dataSEIR)

# %%
beta = 0.01324
gI   = 1/7           # Assume combined incubation and recovery time of three weeks
kI = 32;              # stages of SIkR
I0 = np.zeros((kI,M));
for i in range(kI):
    I0[i, 6:13]=14;  I0[i, 2:6]=13
S0 = np.zeros(M)  
for i in range(M) :
    S0[i] = Ni[i] - np.sum(I0[:,i])
I0 = np.reshape(I0, kI*M)/kI


parameters = {'beta':beta, 'gI':gI, 'kI':kI}
model = pyross.deterministic.SIkR(parameters, M, Ni)
dataSIkR=model.simulate(S0, I0, contactMatrix, Tf, Nf)
ISIkR = model.I(dataSIkR)

# %%
beta = 0.02524
gI   = 1/7           # Assume combined incubation and recovery time of three weeks
kI = 32;              # stages of SIkR
kE = 32
gE = 1/2.72
I0 = np.zeros((kI,M));
for i in range(kI):
    I0[i, 6:13]=14;  I0[i, 2:6]=13
S0 = np.zeros(M)  
for i in range(M) :
    S0[i] = Ni[i] - np.sum(I0[:,i])
I0 = np.reshape(I0, kI*M)/kI

E0 = np.zeros((kE,M));
E0 = np.reshape(E0, kE*M)


parameters = {'beta':beta, 'gI':gI, 'gE':gE, 'kE':kE, 'kI':kI}
model = pyross.deterministic.SEkIkR(parameters, M, Ni)
dataSIkR=model.simulate(S0, E0, I0, contactMatrix, Tf, Nf)
ISEkIkR = model.I(dataSIkR)

# %%
asIsSIR = IsSIR.sum(axis=1)
asIsSEIR = IsSEIR.sum(axis=1)
asISIkR = ISIkR.sum(axis=1)
#asISEkIkR = ISEkIkR.sum(axis=1)


fig = plt.figure(num=None, figsize=(28, 8), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 26}); t = dataSEIR['t']; 

plt.plot(t, asIsSIR, '-', lw=4, color='#A60628', label='SIR', alpha=0.8)
plt.plot(t, asIsSEIR, '-', lw=4, color='#348ABD', label='SEIR', alpha=0.8)
plt.plot(t, asISIkR, '-', lw=4, color='g', label='SIkR', alpha=0.8)
#plt.plot(t, asISEkIkR, '-', lw=4, color='', label='SIkR', alpha=0.8)
plt.xticks(np.arange(0, 200, 14),('4 Mar','18 Mar','1 Apr','15 Apr','29 Apr','13 May','27 May','10Jun'));
plt.fill_between(t[300:], 0, np.max(asIsSEIR), color="#A60628", alpha=0.2)


plt.autoscale(enable=True, axis='x', tight=True); plt.legend()
plt.ylabel('Infected individuals');
#plt.ylim(0, 1600); plt.xlim(0, Tf);
