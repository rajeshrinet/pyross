# %%
# %%capture
## compile PyRoss for this notebook
import os
owd = os.getcwd()
os.chdir('../../')
# %run setup.py install
os.chdir(owd)

# %%
# %matplotlib inline
import numpy as np
import pyross
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#from matplotlib import rc; rc('text', usetex=True)

# %% [markdown]
# ## 1) Set up the model and generate a trajectory
# We generate a test trajectory of the SIR class (with constant influx of infecteds until day 10) on a population with two age groups.

# %%
M = 2                # the population has two age groups
N = 5e4              # and this is the total population

# set the age structure
fi = np.array([0.25, 0.75])  # fraction of population in age group
Ni = N*fi

# set the contact structure
C = np.array([[18., 9.], [3., 12.]])


def contactMatrix(t):   
    return C

# duration of simulation and data file
Tf = 100;  
Nf = Tf+1; 


# set up initial condition
Ia0 = np.array([10, 10])  # each age group has asymptomatic infectives
Is0 = np.array([10, 10])  # and also symptomatic infectives
R0  = np.array([0, 0])    # there are no recovered individuals initially
S0  = Ni - (Ia0 + Is0 + R0)

x0 = np.concatenate((S0, Ia0, Is0))

beta = 0.02
alpha = 0.2
gIa = 1/7 
gIs = 1/7 
fsa = 1
ki = 1000 # influx before travel ban
kf = 10  # influx after travel ban


def contactMatrix(t):
    return C

# %%
parameters = {
    'alpha' : alpha, 
    'beta' : beta, 
    'gIa' : gIa, 
    'gIs' : gIs,
    'ki' : ki, 
    'kf' : kf
}

true_parameters = parameters.copy()

def parameter_mapping(input_parameters, tt):
    output_parameters = {
        'betaIa' : input_parameters['beta'] * input_parameters['alpha'],
        'betaIs' : input_parameters['beta'] * (1 - input_parameters['alpha']),
        'gIa' : input_parameters['gIa'],
        'gIs' : input_parameters['gIs'],
        'ka'  : input_parameters['ki'] * input_parameters['alpha'],       # influx of asymtpomatic infecteds
        'ks'  : input_parameters['ki'] * (1 - input_parameters['alpha'])  # influx of symtpomatic infecteds
    }
    if tt>=10:
        output_parameters['ka'] = input_parameters['kf'] * input_parameters['alpha']
        output_parameters['ks'] = input_parameters['kf'] * (1 - input_parameters['alpha'])
    return output_parameters


model_spec = {
    "classes" : ["S", "Ia", "Is"],

    "S" : {
        "linear"    : [],
        "infection" : [ ["Ia", "-betaIa"], ["Is", "-betaIa"], ["Ia", "-betaIs"], ["Is", "-betaIs"]]
    },
    "Ia" : {
        "linear"    : [ ["Ia", "-gIa"] ],
        "infection" : [ ["Ia", "betaIa"], ["Is", "betaIa"] ],
        "constant"  : [ ["ka"] ]
    }, 
    "Is" :{
        "linear"    : [ ["Is", "-gIs"] ],
        "infection" : [ ["Is", "betaIs"], ["Ia", "betaIs"]],
        "constant" :  [ ["ks"] ]
    }
}

# %%
# use pyross stochastic to generate traj and save 
sto_model = pyross.stochastic.Spp(model_spec, parameters, M, Ni, time_dep_param_mapping=parameter_mapping)
data = sto_model.simulate(x0, contactMatrix, Tf, Nf)
data_array = data['X']

# %%
fig = plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 22})
t = data['t']

plt.fill_between(t, 0, np.sum(data_array[:, :M], axis=1),  alpha=0.3)
plt.plot(t, np.sum(data_array[:, :M], axis=1), '-', label='S', lw=4)

plt.fill_between(t, 0, np.sum(data_array[:, M:2*M], axis=1), alpha=0.3)
plt.plot(t, np.sum(data_array[:, M:2*M], axis=1), '-', label='Ia', lw=4)

plt.fill_between(t, 0, np.sum(data_array[:, 2*M:3*M], axis=1), alpha=0.3)
plt.plot(t, np.sum(data_array[:, 2*M:3*M], axis=1), '-', label='Is', lw=4)

plt.legend(fontsize=26)
plt.grid() 
plt.xlabel(r'time') 
plt.autoscale(enable=True, axis='x', tight=True)

# %%
# load the data and rescale to intensive variables 
Tf_inference = 20 # truncate to only getting the first few datapoints 
Nf_inference = Tf_inference+1

x = (data_array[:Nf_inference]).astype('float')

# %% [markdown]
# ### 2) Inference

# %%
inference_parameters = parameters.copy()

# initialise the estimator 
estimator = pyross.inference.Spp(model_spec, inference_parameters, M, Ni, time_dep_param_mapping=parameter_mapping)
# check integrate 
logp = estimator.obtain_minus_log_p(inference_parameters, x, Tf_inference, contactMatrix)
print(logp)
# Out:
# 715.7585665851088

# %%
# Define the prior (log normal prior around guess of parameter with defined std. deviation)
alpha_g = 0.1
alpha_std = 0.1 

beta_g = 0.01
beta_std = 0.01

gIa_g = 0.1
gIa_std = 0.1

gIs_g = 0.1
gIs_std = 0.1

ki_g = 800
ki_std = 500

kf_g = 8
kf_std = 5

# compute -log_p for the initial guess 
guessed_parameters = {
    'alpha' : alpha_g, 
    'beta' : beta_g, 
    'gIa' : gIa_g, 
    'gIs' : gIs_g,
    'ki'  : ki_g,
    'kf'  : kf_g
}

logp = estimator.obtain_minus_log_p(guessed_parameters, x, Tf_inference, contactMatrix)
print(logp)
# Out:
# 13231.795116678013

# %%
## inference 
ftol = 1e-6  # Stopping criterion for minimisation (relative change in function value)
eps = 1e-4 
param_priors = {
    'alpha':{
        'mean': alpha_g, 
        'std': alpha_std, 
        'bounds': [eps, 0.5]
    }, 
    'beta':{
        'mean': beta_g, 
        'std': beta_std, 
        'bounds': [eps, 0.5]
    }, 
    'gIa':{
        'mean': gIa_g, 
        'std': gIa_std, 
        'bounds': [eps, 0.6]
    }, 
    'gIs':{
        'mean': gIs_g, 
        'std': gIs_std, 
        'bounds': [eps, 0.6]
    },
    'ki':{
        'mean': ki_g, 
        'std': ki_std, 
        'bounds': [eps, 10000]
    },
    'kf':{
        'mean': kf_g, 
        'std': kf_std, 
        'bounds': [eps, 10000]
    }
}

estimator.set_lyapunov_method('euler')
res = estimator.infer_parameters(x, Tf_inference, contactMatrix, param_priors, 
                                    tangent=False, 
                                    global_max_iter=20, local_max_iter=200, 
                                    global_atol=1, ftol=ftol, verbose=True)
# Out:
# Starting global minimisation...
# (8_w,16)-aCMA-ES (mu_w=4.8,w_1=32%) in dimension 6 (seed=1701282174, Tue Jul 14 16:16:42 2020)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     16 6.475613653413782e+03 1.0e+00 1.15e+00  1e-02  5e+02 0:00.1
#     2     32 4.762570113490131e+03 1.6e+00 1.04e+00  1e-02  5e+02 0:00.4
#     3     48 4.620900854981814e+03 1.7e+00 9.81e-01  1e-02  4e+02 0:00.6
#    16    256 7.838700219075621e+02 3.8e+00 2.84e-01  2e-03  6e+01 0:03.6
# Global optimisation: Maximum number of iterations reached.
# Optimal value (global minimisation):  743.7783831925819
# Starting local minimisation...
# Optimal value (local minimisation):  721.83192383515

# %%
print("True parameters:")
print(inference_parameters)

print("\nInferred parameters:")
best_estimates = res['map_dict']
print(best_estimates)
# Out:
# True parameters:
# {'alpha': 0.2, 'beta': 0.02, 'gIa': 0.14285714285714285, 'gIs': 0.14285714285714285, 'ki': 1000, 'kf': 10}
#
# Inferred parameters:
# {'alpha': 0.19799224589553038, 'beta': 0.020057111286308184, 'gIa': 0.14001580746185596, 'gIs': 0.14271273678247087, 'ki': 998.103420879392, 'kf': 9.958839886609272}

# %%
Nf = 101
Tf = Nf-1

estimator.set_det_model(best_estimates)
x_det = estimator.integrate(x[0], 0, Tf, Nf)
x = data['X']
fig = plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 22})
plt.plot(np.sum(x_det[:, :M], axis=1), label='Inferred S')
plt.plot(np.sum(x[:, :M], axis=1), label='True S')
plt.plot(np.sum(x_det[:, M:2*M], axis=1), label='Inferred Ia')
plt.plot(np.sum(x[:, M:2*M], axis=1), label='True Ia')
plt.plot(np.sum(x_det[:, 2*M:3*M], axis=1), label='Inferred Ia')
plt.plot(np.sum(x[:, 2*M:3*M], axis=1), label='True Ia')
plt.axvspan(0, Nf_inference, 
           label='Used for inference',
           alpha=0.3, color='dodgerblue')
plt.legend()
plt.show()
