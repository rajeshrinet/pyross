# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc; rc('text', usetex=True)
import pandas as pd

# %%
my_data = np.genfromtxt('../../data/age_structures/SouthAfrica-2019.csv', delimiter=',', skip_header=1)
aM, aF = my_data[:, 1], my_data[:, 2]

aM = 100*aM/np.sum(aM)
aF = 100*aF/np.sum(aF)

# %%
fig = plt.figure(num=None, figsize=(8, 12), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 22})

sAge = np.arange((np.size(aM)))

plt.barh(sAge, aM, color="#348ABD", label='Male', alpha=0.6)
plt.barh(sAge, -aF,color='#A60628', label='Female', alpha=0.6)

plt.legend(fontsize=26); plt.grid()

# %%
my_data = pd.read_excel('../../data/contact_matrices_152_countries/MUestimates_home_2.xlsx', sheet_name='South Africa',index_col=None, header=None)
MU = np.array(my_data)

#plt.imshow(MU, cmap=plt.cm.Blues, interpolation='none', origin='lower'); plt.axis('off')
plt.pcolor(MU, cmap=plt.cm.get_cmap('Blues', 8)); plt.axis('off'); #plt.colorbar()

# %%
my_data = pd.read_excel('../../data/contact_matrices_152_countries/MUestimates_work_2.xlsx', sheet_name='South Africa',index_col=None, header=None)
MU = np.array(my_data)

#plt.imshow(MU, cmap=plt.cm.Blues, interpolation='none', origin='lower'); plt.axis('off')
plt.pcolor(MU, cmap=plt.cm.Blues); plt.axis('off')
# Out:
# (0.0, 16.0, 0.0, 16.0)

# %%
my_data = pd.read_excel('../../data/contact_matrices_152_countries/MUestimates_school_2.xlsx', sheet_name='South Africa',index_col=None, header=None)
MU = np.array(my_data)

#plt.imshow(MU, cmap=plt.cm.Blues, interpolation='none', origin='lower'); plt.axis('off')
plt.pcolor(MU, cmap=plt.cm.Blues); plt.axis('off')
# Out:
# (-0.5, 15.5, -0.5, 15.5)

# %%
my_data = pd.read_excel('../../data/contact_matrices_152_countries/MUestimates_other_locations_2.xlsx', sheet_name='South Africa',index_col=None, header=None)
MU = np.array(my_data)

#plt.imshow(MU, cmap=plt.cm.Blues, interpolation='none', origin='lower'); plt.axis('off')
plt.pcolor(MU, cmap=plt.cm.Blues); plt.axis('off')
# Out:
# (0.0, 16.0, 0.0, 16.0)

# %%
my_data = pd.read_excel('../../data/contact_matrices_152_countries/MUestimates_all_locations_2.xlsx', sheet_name='South Africa',index_col=None, header=None)
MU = np.array(my_data)

#plt.imshow(MU, cmap=plt.cm.Blues, interpolation='none', origin='lower'); plt.axis('off')

plt.pcolor(MU, cmap=plt.cm.Blues); plt.axis('off')
# Out:
# (0.0, 16.0, 0.0, 16.0)
